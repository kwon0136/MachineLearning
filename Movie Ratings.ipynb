# %%
# Download the movie ratings and IMDB movie titles from the sample datasets collection
library("AzureML")
ws <- workspace()
ratings <- download.datasets(ws, "Movie Ratings")
titles <- download.datasets(ws,"IMDB Movie Titles")

# %%
# Examine the first few rows in each dataset
head(ratings) 
head(titles)
# Out:
#   UserId MovieId Rating Timestamp
# 1 1        68646 10     1381620027
# 2 1       113277 10     1379466669
# 3 2       454876  8     1394818630
# 4 2       790636  7     1389963947
# 5 2       816711  8     1379963769
# 6 2      1091191  7     1391173869
#   Movie.ID Movie.Name
# 1    8     Edison Kinetoscopic Record of a Sneeze (1894)
# 2   91     Le manoir du diable (1896)
# 3  417     Le voyage dans la lune (1902)
# 4  628     The  s of Dollie (1908)
# 5  833     The Country Doctor (1909)
# 6 1223     Frankenstein (1910)

# %%
# Merge the two datasets over the movie id
movieData <- merge(ratings, titles, by.x = "MovieId", by.y = "Movie.ID")
head(movieData)
# Out:
#   MovieId UserId Rating Timestamp
# 1   8      3296  5      1396981211
# 2  91      4879  6      1385233195
# 3 417     15463  7      1392806422
# 4 628     19326  4      1385729728
# 5 628      8178  5      1381446481
# 6 833     19326  3      1385738847
#   Movie.Name
# 1 Edison Kinetoscopic Record of a Sneeze (1894)
# 2 Le manoir du diable (1896)
# 3 Le voyage dans la lune (1902)
# 4 The  s of Dollie (1908)
# 5 The  s of Dollie (1908)
# 6 The Country Doctor (1909)

# %%
# What is the average rating for each movie?
# install.packages("dplyr")
library(dplyr)

select(movieData, MovieId, Movie.Name, Rating) %>%
  group_by(Movie.Name) %>%
  summarize("MeanRating" = mean(Rating)) %>%
  arrange(desc(MeanRating))
# Out:
# Warning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in grepl("^\\s*$", values):
# âinput string 1 is invalid in this localeâWarning message in grepl("^\\s*$", values):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâWarning message in FUN(X[[i]], ...):
# âinput string 1 is invalid in this localeâERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)
# Warning message in grepl("<html.*>", data[["text/html"]], ignore.case = TRUE):
# âinput string 1 is invalid in this localeâ
#       Movie.Name                                  MeanRating
# 1       Story (2013)                              10
# 2     -1945                                       10
# 3     ? nos amours. (1983)                        10
# 4     12 OClock Boys (2013)Biography              10
# 5     13 Ghosts (1960)                            10
# 6     13 Rue Madeleine (1947)                     10
# 7     1492 Conquest of Paradise (1992)Biography   10
# 8     17 Seconds (2013)                           10
# 9     2 Kings (2011)                              10
# 10    2by4 (1998)                                 10
# 11    44 (2007)                                   10
# 12    46-okunen no koi (2006)                     10
# 13    6 Month Rule (2011)                         10
# 14    846 (2011)                                  10
# 15    903 (2012)                                  10
# 16    A Decade Under the Influence (2003)         10
# 17    A Different Tree (2013)                     10
# 18    A Dirty Shame (2004)                        10
# 19    A Good Day to Die (2010)BiographyNews       10
# 20    A Man Betrayed (1941)                       10
# 21    A Most Wanted Man (2014)                    10
# 22    A Passage to India (1984)                   10
# 23    A Patch of Blue (1965)                      10
# 24    A Soldiers Story (1984)                     10
# 25    A Tale of Two Pastries (2012)               10
# 26    A Terrorist Ate My Brain (2006)             10
# 27    A Wonderful Moment (2013)                   10
# 28    A Year with Armin Van Buuren (2012)         10
# 29    A.B.S (2012)                                10
# 30    A.R.O.G (2008)                              10
# ...   ...                                         ...
# 15705 The Giant Spider Invasion (1975)            1
# 15706 The Guillotines (2012)                      1
# 15707 The Kane Files Life of Trial (2010)         1
# 15708 The Last Broadcast (1998)                   1
# 15709 The Last Leprechaun (1998)                  1
# 15710 The Master of Disguise (2002)               1
# 15711 The Mighty Macs (2009)                      1
# 15712 The Mistress of Spices (2005)               1
# 15713 The New Year (2010)                         1
# 15714 The Nutcracker in 3D (2009)                 1
# 15715 The Oregonian (2011)                        1
# 15716 The Party at Kitty and Studs (1970)Adult    1
# 15717 The Ringer (2005)                           1
# 15718 The Secret Village (2013)                   1
# 15719 The Taking (2013)                           1
# 15720 The Tree (2010)                             1
# 15721 The Underground   Movie (1999)              1
# 15722 Total Force (1997)                          1
# 15723 Tre solar (2004)                            1
# 15724 Treachery (2013)                            1
# 15725 Un altro pianeta (2008)                     1
# 15726 Viva Cuba (2005)                            1
# 15727 Wild Seven (2006)                           1
# 15728 Zapata - El sue\xa4o del h\x82roe (2004)    1
# 15729 Zindagi 50 50 (2013)                        1
# 15730 Zombex (2013)                               1
# 15731 Zombie Nation (2004)                        1
# 15732 Zombie Undead (2010)                        1
# 15733 \xadVivan los novios (1970)                 1
# 15734 El rey de Najayo (2012)                     0

# %%
# Install the lubridate and xts packages
install.packages("lubridate")
library(lubridate)

install.packages("xts")
library(xts)
# Out:
# Installing package into â/home/nbuser/Râ
# (as âlibâ is unspecified)
# also installing the dependency âstringrâ
#
# Warning message in install.packages("lubridate"):
# âinstallation of package âlubridateâ had non-zero exit statusâ
# Attaching package: âlubridateâ
#
# The following object is masked from âpackage:baseâ:
#
#     date
#
# Installing package into â/home/nbuser/Râ
# (as âlibâ is unspecified)
# Loading required package: zoo
#
# Attaching package: âzooâ
#
# The following objects are masked from âpackage:baseâ:
#
#     as.Date, as.Date.numeric
#
#
# Attaching package: âxtsâ
#
# The following objects are masked from âpackage:dplyrâ:
#
#     first, last
#
# The following object is masked from âpackage:AzureMLâ:
#
#     endpoints

# %%
# Step 1: Convert the dataset into an xts object (the Timestamp is a POSIXct datetime)
xtsMovieData <- xts(movieData[c("MovieId", "UserId", "Rating", "Movie.Name")], order.by=as.POSIXct(movieData$Timestamp, origin = "1970-01-01"))
head(xtsMovieData)
# Out:
#                     MovieId   UserId  Rating
# 2013-02-28 14:38:27 "2171847" "18507" " 6"
# 2013-02-28 14:43:44 " 444778" "16458" " 8"
# 2013-02-28 14:47:18 "1411238" " 3136" " 6"
# 2013-02-28 14:58:23 "1496422" "21655" " 7"
# 2013-02-28 15:00:53 " 118799" "16777" " 5"
# 2013-02-28 15:04:39 " 338013" "16777" " 4"
#                     Movie.Name
# 2013-02-28 14:38:27 "Dead Mine (2012) "
# 2013-02-28 14:43:44 "Mah nakorn (2004) "
# 2013-02-28 14:47:18 "No Strings Attached (2011)"
# 2013-02-28 14:58:23 "The Paperboy (2012)"
# 2013-02-28 15:00:53 "La vita \x8a bella (1997) "
# 2013-02-28 15:04:39 "Eternal Sunshine of the Spotless Mind (2004)"

# %%
# Step 2: Count the number of ratings posted per day
ratingsPerDay <- apply.daily(xtsMovieData, function(data) { nrow(data$Rating) })
head(ratingsPerDay)
# Out:
#                     [,1]
# 2013-02-28 23:55:41  245
# 2013-03-01 23:53:21  509
# 2013-03-02 23:55:52  672
# 2013-03-03 23:58:43  905
# 2013-03-04 23:58:42  570
# 2013-03-05 23:58:38  433

# %%
# Install the broom and ggplot2 packages
install.packages("broom")
library(broom)

install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into â/home/nbuser/Râ
# (as âlibâ is unspecified)
# also installing the dependency âgenericsâ
#
# Installing package into â/home/nbuser/Râ
# (as âlibâ is unspecified)
# Warning message in install.packages("ggplot2"):
# âinstallation of package âggplot2â had non-zero exit statusâ

# %%
# Step 3: Graph the results
graphData <- tidy(ratingsPerDay)
graphData$index <- as.POSIXct(graphData$index,  origin="1970-01-01")

options(repr.plot.width=15, repr.plot.height=4)
ggplot(graphData, aes(x = index, y = value)) +
  ggtitle("Ratings Posted Per Day") +
  xlab("Date") +
  ylab("Number of Ratings") +
  geom_line(color = "blue")
